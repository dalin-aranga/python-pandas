# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pokemon_data.csv', index_col=0)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.shape
# Out:
# (800, 11)

# %%
df.iloc[5:7]
# Out:
#          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 5  Charmeleon   Fire     NaN  58      64       58       80       65     80
# 6   Charizard   Fire  Flying  78      84       78      109       85    100
#
#    Generation  Legendary
# #
# 5           1      False
# 6           1      False

# %%
df.iloc[4,2]
# Out:
# nan

# %%
for index, row in df.iterrows():
    print(index,row)
# Out:
# 1 Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 1, dtype: object
# 2 Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 2, dtype: object
# 3 Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 3, dtype: object
# 3 Name          VenusaurMega Venusaur
# Type 1                        Grass
# ...

# %%
df.loc[df['Type 1']=='Fire']
# Out:
#                           Name Type 1    Type 2   HP  Attack  Defense  \
# #
# 4                   Charmander   Fire       NaN   39      52       43
# 5                   Charmeleon   Fire       NaN   58      64       58
# 6                    Charizard   Fire    Flying   78      84       78
# 6    CharizardMega Charizard X   Fire    Dragon   78     130      111
# 6    CharizardMega Charizard Y   Fire    Flying   78     104       78
# 37                      Vulpix   Fire       NaN   38      41       40
# 38                   Ninetales   Fire       NaN   73      76       75
# 58                   Growlithe   Fire       NaN   55      70       45
# 59                    Arcanine   Fire       NaN   90     110       80
# 77                      Ponyta   Fire       NaN   50      85       55
# 78                    Rapidash   Fire       NaN   65     100       70
# 126                     Magmar   Fire       NaN   65      95       57
# ...

# %%
df1 = df.describe()

# %%
df1
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    69.258750   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.534669   32.457366   31.183501   32.722294   27.828916   29.060474
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     65.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     80.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    255.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        Generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000

# %%
df1.HP
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64

# %%
df.sort_values('Name', ascending=True).head()
# Out:
#                         Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 460                Abomasnow    Grass    Ice  90      92       75       92
# 460  AbomasnowMega Abomasnow    Grass    Ice  90     132      105      132
# 63                      Abra  Psychic    NaN  25      20       15      105
# 359                    Absol     Dark    NaN  65     130       60       75
# 359          AbsolMega Absol     Dark    NaN  65     150       60      115
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 460       85     60           4      False
# 460      105     30           4      False
# 63        55     90           1      False
# 359       60     75           3      False
# 359       60    115           3      False

# %%
df.sort_values('Name', ascending=False).head()
# Out:
#                  Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 718  Zygarde50% Forme  Dragon  Ground  108     100      121       81       95
# 634          Zweilous    Dark  Dragon   72      85       70       65       70
# 41              Zubat  Poison  Flying   40      45       35       30       40
# 570             Zorua    Dark     NaN   40      65       40       80       40
# 571           Zoroark    Dark     NaN   60     105       60      120       60
#
#      Speed  Generation  Legendary
# #
# 718     95           6       True
# 634     58           5      False
# 41      55           1      False
# 570     65           5      False
# 571    105           5      False

# %%
df.sort_values(['Type 1','HP'],ascending=[0,1]).head()
# Out:
#          Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 129  Magikarp  Water    NaN  20      10       55       15       20     80
# 349    Feebas  Water    NaN  20      15       20       10       55     80
# 90   Shellder  Water    NaN  30      65      100       45       25     40
# 98     Krabby  Water    NaN  30     105       90       25       25     50
# 116    Horsea  Water    NaN  30      40       70       70       25     60
#
#      Generation  Legendary
# #
# 129           1      False
# 349           3      False
# 90            1      False
# 98            1      False
# 116           1      False

# %%
df['Total'] = df.HP+df.Attack +df.Speed

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# #
# 1       65     45           1      False    139
# 2       80     60           1      False    182
# 3      100     80           1      False    242
# 3      120     80           1      False    260
# 4       50     65           1      False    156

# %%
df.drop(columns=['Total'],inplace=True)
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:,3:9].sum(axis=1)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# #
# 1       65     45           1      False    318
# 2       80     60           1      False    405
# 3      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
cols = list(df.columns)
df = df[cols[0:4]+[cols[-1]]+cols[4:11]]

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Total  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45    318      49       49       65
# 2                Ivysaur  Grass  Poison  60    405      62       63       80
# 3               Venusaur  Grass  Poison  80    525      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80    625     100      123      122
# 4             Charmander   Fire     NaN  39    309      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.to_csv('modifie.csv')

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Total  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45    318      49       49       65
# 2                Ivysaur  Grass  Poison  60    405      62       63       80
# 3               Venusaur  Grass  Poison  80    525      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80    625     100      123      122
# 4             Charmander   Fire     NaN  39    309      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')& (df['HP']>70)]
# Out:
#                       Name Type 1  Type 2   HP  Total  Attack  Defense  \
# #
# 3                 Venusaur  Grass  Poison   80    525      82       83
# 3    VenusaurMega Venusaur  Grass  Poison   80    625     100      123
# 45               Vileplume  Grass  Poison   75    490      80       85
# 71              Victreebel  Grass  Poison   80    490     105       65
# 591              Amoonguss  Grass  Poison  114    464      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 3        100      100     80           1      False
# 3        122      120     80           1      False
# 45       110       90     50           1      False
# 71       100       70     70           1      False
# 591       85       80     30           5      False

# %%
new_df = df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')& (df['HP']>70)]

# %%
new_df
# Out:
#                       Name Type 1  Type 2   HP  Total  Attack  Defense  \
# #
# 3                 Venusaur  Grass  Poison   80    525      82       83
# 3    VenusaurMega Venusaur  Grass  Poison   80    625     100      123
# 45               Vileplume  Grass  Poison   75    490      80       85
# 71              Victreebel  Grass  Poison   80    490     105       65
# 591              Amoonguss  Grass  Poison  114    464      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 3        100      100     80           1      False
# 3        122      120     80           1      False
# 45       110       90     50           1      False
# 71       100       70     70           1      False
# 591       85       80     30           5      False

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#                           Name    Type 1    Type 2   HP  Total  Attack  \
# #
# 3        VenusaurMega Venusaur     Grass    Poison   80    625     100
# 6    CharizardMega Charizard X      Fire    Dragon   78    634     130
# 6    CharizardMega Charizard Y      Fire    Flying   78    634     104
# 9      BlastoiseMega Blastoise     Water       NaN   79    630     103
# 15       BeedrillMega Beedrill       Bug    Poison   65    495     150
# 18         PidgeotMega Pidgeot    Normal    Flying   83    579      80
# 65       AlakazamMega Alakazam   Psychic       NaN   55    590      50
# 80         SlowbroMega Slowbro     Water   Psychic   95    590      75
# 94           GengarMega Gengar     Ghost    Poison   60    600      65
# 115  KangaskhanMega Kangaskhan    Normal       NaN  105    590     125
# 127          PinsirMega Pinsir       Bug    Flying   65    600     155
# 130      GyaradosMega Gyarados     Water      Dark   95    640     155
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#                     Name   Type 1  Type 2   HP  Total  Attack  Defense  \
# #
# 1              Bulbasaur    Grass  Poison   45    318      49       49
# 2                Ivysaur    Grass  Poison   60    405      62       63
# 3               Venusaur    Grass  Poison   80    525      82       83
# 4             Charmander     Fire     NaN   39    309      52       43
# 5             Charmeleon     Fire     NaN   58    405      64       58
# ..                   ...      ...     ...  ...    ...     ...      ...
# 718     Zygarde50% Forme   Dragon  Ground  108    600     100      121
# 719              Diancie     Rock   Fairy   50    600     100      150
# 720  HoopaHoopa Confined  Psychic   Ghost   80    600     110       60
# 720   HoopaHoopa Unbound  Psychic    Dark   80    680     160       60
# 721            Volcanion     Fire   Water   80    600     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1         65       65     45           1      False
# ...

# %%
import re

# %%
df.loc[df['Name'].str.contains('pi[a-z]*',flags=re.I, regex=True)]
# Out:
#                         Name    Type 1    Type 2   HP  Total  Attack  Defense  \
# #
# 10                  Caterpie       Bug       NaN   45    195      30       35
# 16                    Pidgey    Normal    Flying   40    251      45       40
# 17                 Pidgeotto    Normal    Flying   63    349      60       55
# 18                   Pidgeot    Normal    Flying   83    479      80       75
# 18       PidgeotMega Pidgeot    Normal    Flying   83    579      80       80
# 25                   Pikachu  Electric       NaN   35    320      55       40
# 37                    Vulpix      Fire       NaN   38    299      41       40
# 70                Weepinbell     Grass    Poison   65    390      90       50
# 78                  Rapidash      Fire       NaN   65    500     100       70
# 127                   Pinsir       Bug       NaN   65    500     125      100
# 127        PinsirMega Pinsir       Bug    Flying   65    600     155      120
# ...

# %%
df.loc[df['Type 1']=='Fire','Type 1']='Dalin'

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Total  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45    318      49       49       65
# 2                Ivysaur  Grass  Poison  60    405      62       63       80
# 3               Venusaur  Grass  Poison  80    525      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80    625     100      123      122
# 4             Charmander  Dalin     NaN  39    309      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.loc[df['Type 1']=='Dalin','Type 1']='Fire'

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Total  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45    318      49       49       65
# 2                Ivysaur  Grass  Poison  60    405      62       63       80
# 3               Venusaur  Grass  Poison  80    525      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80    625     100      123      122
# 4             Charmander   Fire     NaN  39    309      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.loc[df['Type 1']=='Fire','Legendary']=True

# %%
df
# Out:
#                       Name   Type 1  Type 2  HP  Total  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison  45    318      49       49
# 2                  Ivysaur    Grass  Poison  60    405      62       63
# 3                 Venusaur    Grass  Poison  80    525      82       83
# 3    VenusaurMega Venusaur    Grass  Poison  80    625     100      123
# 4               Charmander     Fire     NaN  39    309      52       43
# ..                     ...      ...     ...  ..    ...     ...      ...
# 719                Diancie     Rock   Fairy  50    600     100      150
# 719    DiancieMega Diancie     Rock   Fairy  50    700     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost  80    600     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark  80    680     160       60
# 721              Volcanion     Fire   Water  80    600     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df.loc[df['Total']>500,['Generation','Legendary']]= 'Tutu'

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Total  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45    318      49       49       65
# 2                Ivysaur  Grass  Poison  60    405      62       63       80
# 3               Venusaur  Grass  Poison  80    525      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80    625     100      123      122
# 4             Charmander   Fire     NaN  39    309      52       43       60
#
#    Sp. Def  Speed Generation Legendary
# #
# 1       65     45          1     False
# 2       80     60          1     False
# 3      100     80       Tutu      Tutu
# 3      120     80       Tutu      Tutu
# 4       50     65          1      True

# %%
df = pd.read_csv('pokemon_data.csv', index_col=0)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.groupby(['Type 1']).mean()
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed  \
# Type 1
# Bug       56.884058   70.971014   70.724638  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Electric  59.795455   69.090909   66.295455  90.022727  73.704545   84.500000
# Fairy     74.117647   61.529412   65.705882  78.529412  84.705882   48.588235
# Fighting  69.851852   96.777778   65.925926  53.111111  64.703704   66.074074
# Fire      69.903846   84.769231   67.769231  88.980769  72.211538   74.442308
# Flying    70.750000   78.750000   66.250000  94.250000  72.500000  102.500000
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Grass     67.271429   73.214286   70.800000  77.500000  70.428571   61.928571
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed  \
# Type 1
# Steel     65.222222   92.703704  126.370370  67.518519  80.629630   55.259259
# Rock      65.363636   92.863636  100.795455  63.340909  75.477273   55.909091
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Water     72.062500   74.151786   72.946429  74.812500  70.517857   65.964286
# Ice       72.000000   72.750000   71.416667  77.541667  76.291667   63.458333
# Grass     67.271429   73.214286   70.800000  77.500000  70.428571   61.928571
# Bug       56.884058   70.971014   70.724638  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Poison    67.250000   74.678571   68.821429  60.428571  64.392857   63.571429
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#           Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug         69      52   69      69       69       69       69     69
# Dark        31      21   31      31       31       31       31     31
# Dragon      32      21   32      32       32       32       32     32
# Electric    44      17   44      44       44       44       44     44
# Fairy       17       2   17      17       17       17       17     17
# Fighting    27       7   27      27       27       27       27     27
# Fire        52      24   52      52       52       52       52     52
# Flying       4       2    4       4        4        4        4      4
# Ghost       32      22   32      32       32       32       32     32
# Grass       70      37   70      70       70       70       70     70
# Ground      32      19   32      32       32       32       32     32
# Ice         24      11   24      24       24       24       24     24
# ...

# %%
df['count'] = 1

df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
