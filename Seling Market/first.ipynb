# %%
import pandas as pd
import os

list=[]
for file in os.listdir('/home/dalin/jupyter/Sales_Data'):
    list.append(file)

# %%
df = pd.DataFrame()
for file in list:
    df1 = pd.read_csv('/home/dalin/jupyter/Sales_Data/'+file)
    df=pd.concat([df,df1])
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 15221   176554    Lightning Charging Cable                1      14.95
# 15222   176555            27in FHD Monitor                1     149.99
# 15223   176556      AAA Batteries (4-pack)                3       2.99
# 15224   176557                      iPhone                1        700
# 15225   176557    Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address
# ...

# %%
df.tail()
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 15221   176554  Lightning Charging Cable                1      14.95
# 15222   176555          27in FHD Monitor                1     149.99
# 15223   176556    AAA Batteries (4-pack)                3       2.99
# 15224   176557                    iPhone                1        700
# 15225   176557  Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address
# 15221  03/24/19 11:14       672 12th St, San Francisco, CA 94016
# 15222  03/22/19 20:27         42 4th St, San Francisco, CA 94016
# 15223  03/14/19 10:29          871 7th St, Los Angeles, CA 90001
# 15224  03/30/19 12:32  83 Washington St, San Francisco, CA 94016
# 15225  03/30/19 12:32  83 Washington St, San Francisco, CA 94016

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 15221   176554    Lightning Charging Cable                1      14.95
# 15222   176555            27in FHD Monitor                1     149.99
# 15223   176556      AAA Batteries (4-pack)                3       2.99
# 15224   176557                      iPhone                1        700
# 15225   176557    Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address
# ...

# %% [markdown]
# ### best month in sales

# %%
df['Month'] = df["Order Date"].str[0:2]
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 15221   176554    Lightning Charging Cable                1      14.95
# 15222   176555            27in FHD Monitor                1     149.99
# 15223   176556      AAA Batteries (4-pack)                3       2.99
# 15224   176557                      iPhone                1        700
# 15225   176557    Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address Month
# ...

# %%
df = df[df['Order Date'].str[0:2]!='Or']
df = df.dropna()
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 15221   176554    Lightning Charging Cable                1      14.95
# 15222   176555            27in FHD Monitor                1     149.99
# 15223   176556      AAA Batteries (4-pack)                3       2.99
# 15224   176557                      iPhone                1        700
# 15225   176557    Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address Month
# ...

# %%
df['Month'] = df['Month'].astype('int32')
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 15221   176554    Lightning Charging Cable                1      14.95
# 15222   176555            27in FHD Monitor                1     149.99
# 15223   176556      AAA Batteries (4-pack)                3       2.99
# 15224   176557                      iPhone                1        700
# 15225   176557    Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address  Month
# ...

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Price Each'] = pd.to_numeric(df['Price Each'])
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#            Order Date                           Purchase Address  Month
# ...

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#            Order Date                           Purchase Address  Month  \
# ...

# %%
month = df.groupby('Month').sum()
month
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
import matplotlib.pyplot as plt

# %%
months = range(1,13,1)
plt.bar(months,month['Sales'])
plt.xticks(months)
plt.xlabel('Month')
plt.ylabel('Sales each month $ bilion')
plt.show()

# %% [markdown]
# ### best sale city

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#            Order Date                           Purchase Address  Month  \
# ...

# %%
df['City'] = df['Purchase Address'].apply(lambda x: x.split(',')[1])
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#            Order Date                           Purchase Address  Month  \
# ...

# %%
df['City_leter'] = df['Purchase Address'].apply(lambda x: x.split(',')[2])
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#            Order Date                           Purchase Address  Month  \
# ...

# %%
df['City'] = df['City']+ '(' +df['City_leter'].str[1:3] +')'
df = df.drop('City_leter',axis=1)
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#            Order Date                           Purchase Address  Month  \
# ...

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#            Order Date                           Purchase Address  Month  \
# ...

# %%
city = df.groupby('City').sum()
city
# Out:
#                     Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta(GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin(TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston(MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas(TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles(CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City(NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland(ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland(OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco(CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle(WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
cites = [city for city, df in df.groupby('City')]
plt.plot(cites,city['Sales'])
plt.xticks(cites,rotation=90)
plt.xlabel('Name Of The city')
plt.ylabel(' Sales amount Bilion($)')
plt.show()

# %%
cites = [city for city, df in df.groupby('City')]
plt.bar(cites,city['Sales'])
plt.xticks(cites,rotation='vertical')
plt.xlabel('Name Of The city')
plt.ylabel(' Sales amount Bilion($)')
# Out:
# Text(0, 0.5, ' Sales amount Bilion($)')

# %% [markdown]
# ### best Hour in sales

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#                Order Date                           Purchase Address  Month  \
# ...

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#                Order Date                           Purchase Address  Month  \
# ...

# %%
df['Hour'] = df['Order Date'].dt.hour
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       236670            Wired Headphones                 2       11.99
# 1       236671  Bose SoundSport Headphones                 1       99.99
# 2       236672                      iPhone                 1      700.00
# 3       236673       AA Batteries (4-pack)                 2        3.84
# 4       236674       AA Batteries (4-pack)                 2        3.84
# ...        ...                         ...               ...         ...
# 15221   176554    Lightning Charging Cable                 1       14.95
# 15222   176555            27in FHD Monitor                 1      149.99
# 15223   176556      AAA Batteries (4-pack)                 3        2.99
# 15224   176557                      iPhone                 1      700.00
# 15225   176557    Lightning Charging Cable                 1       14.95
#
#                Order Date                           Purchase Address  Month  \
# ...

# %%
hour = df.groupby('Hour').sum()
hour
# Out:
#       Quantity Ordered  Price Each  Month       Sales
# Hour
# 0                 4428   709296.70  27554   713721.27
# 1                 2619   458490.00  16657   460866.88
# 2                 1398   233833.64   8507   234851.44
# 3                  928   144726.42   5904   145757.89
# 4                  937   162058.18   6148   162661.01
# 5                 1493   229621.21   9301   230679.82
# 6                 2810   445000.11  17539   448113.00
# 7                 4556   740568.11  28850   744854.12
# 8                 7002  1185970.62  43626  1192348.97
# 9                 9816  1628498.49  60981  1639030.58
# 10               12308  1932665.62  76928  1944286.77
# 11               14005  2288855.18  87654  2300610.24
# 12               14202  2299876.68  89161  2316821.34
# 13               13685  2139743.86  85808  2155389.80
# 14               12362  2072194.77  77836  2083672.73
# 15               11391  1931174.99  72060  1941549.60
# ...

# %%
hours = [hour for hour ,df in df.groupby('Hour')]
plt.bar(hours, hour['Sales'])
plt.xlabel('Hour')
plt.ylabel('Sales in bilion ($)')
# Out:
# Text(0, 0.5, 'Sales in bilion ($)')

# %%
hours = [hour for hour ,df in df.groupby('Hour')]
plt.plot(hours, hour['Sales'])
plt.xlabel('Hour')
plt.ylabel('Sales in bion ($)')
# Out:
# Text(0, 0.5, 'Sales in bion ($)')
